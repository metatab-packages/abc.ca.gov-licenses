# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()

# %%
pkg = mp.jupyter.open_package()
#pkg = mp.jupyter.open_source_package()
pkg
# Out:
# # California Alcohol Licenses
# `abc.ca.gov-licenses-1.1.1` Last Update: 2020-11-26T20:30:18
#
# __
#
#
# This package is a conversion of the California Daily ABC file, so it is current as of the modification date of the package. The main change is the addition of the ``county`` variable, the FIPS code for the county, and the ``tract``, the ACS format geoid version of the tract identifier.
#
#
#
#
# ## Contacts
#
# * **Wrangler** [Eric Busboom](mailto:eric@civicknowledge.com), [Civic Knowledge](http://civicknowledge.com)
#
# ## Resources
#
# * ** [ca_abc_licenses](data/ca_abc_licenses.csv)**. California Alcohol Beverage Control Licenses
#
# ## References
# <ul><li> <strong><a href="https://www.abc.ca.gov/wp-content/uploads/WeeklyExport_CSV.zip#*.csv&start=2&headers=1">abc_licenses_source</a></strong>. Raw ABC data</li><ul>

# %%
pkg.resource('ca_abc_licenses').dataframe()
# Out:
#         license_type  file_number lic_or_app type_status type_orig_iss_date  \
# 0                 20       257948        APP      ACTIVE
# 1                 21       446537        APP      ACTIVE
# 2                 20       515667        APP      ACTIVE
# 3                 20       203684        APP      ACTIVE
# 4                 20       165239        APP      ACTIVE
# ...              ...          ...        ...         ...                ...
# 122076            21       621003        APP        PEND
# 122077            47       621006        APP        PEND
# 122078            47       621005        APP        PEND
# 122079            47       621011        APP        PEND
# 122080          <NA>         <NA>        NaN         NaN                NaN
#
#        expir_date fee_codes dup_counts master_ind  term_in_of_months  ...  \
# 0                       P40                     Y                 12  ...
# 1                       P40                     Y                 12  ...
# 2                       P40                     Y                 12  ...
# 3                       P20                     Y                 12  ...
# 4                        P0                     Y                 12  ...
# ...           ...       ...        ...        ...                ...  ...
# 122076                                          Y                 12  ...
# 122077                                          Y                 12  ...
# 122078                                          Y                 12  ...
# 122079                                          Y                 12  ...
# 122080        NaN       NaN        NaN        NaN               <NA>  ...
#
#              dba_name         mail_addr_1 mail_addr_2     mail_city  \
# 0        CIRCLE K 457     15825 MOJAVE DR               VICTORVILLE
# 1       CIRCLE K 6004     15825 MOJAVE DR               VICTORVILLE
# 2       CIRCLE K 9476     15825 MOJAVE DR               VICTORVILLE
# 3       CIRCLE K 8587     15825 MOJAVE DR               VICTORVILLE
# 4       CIRCLE K 3608     15825 MOJAVE DR               VICTORVILLE
# ...               ...                 ...         ...           ...
# 122076                      22 MICHAEL RD              LADERA RANCH
# 122077                 39626 10TH ST WEST     SUITE F      PALMDALE
# 122078                      1626 N WILCOX        #185   LOS ANGELES
# 122079                      1626 N WILCOX        #185   LOS ANGELES
# 122080            NaN                 NaN         NaN           NaN
#
#        mail_state    mail_zip  prem_county prem_census_tract county  \
# 0              CA       92394    RIVERSIDE           0451.20     65
# 1              CA       92394     MONTEREY           0106.04     53
# 2              CA       92394    SAN DIEGO           0170.43     73
# 3              CA       92394  LOS ANGELES           4003.04     37
# 4              CA       92394       FRESNO           0082.00     19
# ...           ...         ...          ...               ...    ...
# 122076         CA       92694                                  <NA>
# 122077         CA       93551                                  <NA>
# 122078         CA  90028-6206                                  <NA>
# 122079         CA  90028-6206                                  <NA>
# 122080        NaN         NaN          NaN               NaN   <NA>
#
#                      tract
# 0       14000US06065045120
# 1       14000US06053010604
# 2       14000US06073017043
# 3       14000US06037400304
# 4       14000US06019008200
# ...                    ...
# 122076                 NaN
# 122077                 NaN
# 122078                 NaN
# 122079                 NaN
# 122080                 NaN
#
# [122081 rows x 28 columns]
